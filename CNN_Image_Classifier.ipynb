# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Downloading images from google

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation
arguments = {"keywords":"Polar bears,Grizzly bears","limit":50,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Polar bears
# Evaluating...
# Starting Download...
# Image URL: https://polarbearsinternational.org/media/3091/webbanner2_00473-10418_2.jpg
# Completed Image ====> 1. webbanner2_00473-10418_2.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Polar_Bear_-_Alaska_%28cropped%29.jpg/220px-Polar_Bear_-_Alaska_%28cropped%29.jpg
# Completed Image ====> 2. 220px-polar_bear_-_alaska_%28cropped%29.jpg
# Image URL: https://c402277.ssl.cf1.rackcdn.com/photos/14815/images/priority_species_small/Medium_WW22779.jpg?1513098037
# URLError on an image...trying next one... Error: <urlopen error timed out>
# Image URL: https://www.wwf.org.uk/sites/default/files/styles/hero_s/public/2017-03/331871_0.jpg?h=f1ae4142&itok=O8YSVhEO
# Completed Image ====> 3. 331871_0.jpg
# Image URL: https://www.nwf.org/-/media/NEW-WEBSITE/Shared-Folder/Wildlife/Mammals/mammal_polar_bear_cubs_fighting_alaska_michael_henry_600x300.ashx
# ...

# %%
from fastai.imports import *
# Out:
# /root/anaconda3/envs/fastai/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /root/anaconda3/envs/fastai/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /root/anaconda3/envs/fastai/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /root/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "downloads/"
sz=224

# %%
os.listdir(f'{PATH}')
# Out:
# ['Grizzly bears', 'Polar bears']

# %%
files = os.listdir(f'{PATH}Grizzly bears')[:5]
files
# Out:
# ['30. large_brown_bear.jpg',
#  '50. https%3a%2f%2fblueprint-api-production.s3.amazonaws.com%2fuploads%2fcard%2fimage%2f743859%2fef523ae7-c437-4cde-ac09-6d223ee74d35.jpg',
#  '3. grizzly-bear_thumb.ngsversion.1484681402665.adapt.1900.1.jpg',
#  '44. thinkstockphotos-807913938.jpg',
#  '41. 161461-004-ac8173b8.jpg']

# %%
img = plt.imread(f'{PATH}Grizzly bears/{files[0]}')
plt.imshow(img);

# %%
img.shape
# Out:
# (588, 800, 3)

# %%
arch=resnet34
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz))
learn = ConvLearner.pretrained(arch, data, precompute=True)

# %%
learn.fit(0.01,2)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.98401    0.48255    0.7
#     1      0.797892   0.208367   1.0
# [array([0.20837]), 1.0]

# %%
data.classes
# Out:
# ['Grizzly bears', 'Polar bears']

# %%
log_preds = learn.predict()
log_preds.shape
# Out:
# (20, 2)

# %%
log_preds[:10]
# Out:
# array([[-0.28231, -1.40258],
#        [-0.34924, -1.22154],
#        [-0.08491, -2.50833],
#        [-0.28215, -1.40307],
#        [-0.24112, -1.5406 ],
#        [-0.30044, -1.34897],
#        [-0.35022, -1.21921],
#        [-0.11638, -2.20854],
#        [-0.34453, -1.23289],
#        [-0.06313, -2.7939 ]], dtype=float32)

# %%
preds = np.argmax(log_preds, axis=1)  # from log probabilities to 0 or 1
probs = np.exp(log_preds[:,1])

# %%
probs
# Out:
# array([0.24596, 0.29477, 0.0814 , 0.24584, 0.21425, 0.25951, 0.29546, 0.10986, 0.29145, 0.06118, 0.81858,
#        0.81314, 0.80822, 0.88819, 0.87401, 0.84612, 0.85401, 0.88108, 0.92766, 0.7025 ], dtype=float32)

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))

# %%
# 1. A few correct labels at random
plot_val_with_title(rand_by_correct(True), "Correctly classified")
# Out:
# Correctly classified

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
plot_val_with_title(most_by_correct(0, True), "Most correct Grizzly bears")
# Out:
# Most correct Grizzly bears

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct polar bears")
# Out:
# Most correct polar bears

# %%
most_uncertain = np.argsort(np.abs(probs -0.5))[:4]
plot_val_with_title(most_uncertain, "Most uncertain predictions")
# Out:
# Most uncertain predictions

# %%
learn = ConvLearner.pretrained(arch, data, precompute=True)

# %%
lrf=learn.lr_find()
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.768376   0.314526   0.95

# %%
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %%
tfms = tfms_from_model(resnet34, sz, aug_tfms=transforms_side_on, max_zoom=1.1)

# %%
def get_augs():
    data = ImageClassifierData.from_paths(PATH, bs=2, tfms=tfms, num_workers=1)
    x,_ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
ims = np.stack([get_augs() for i in range(6)])

# %%
plots(ims, rows=2)

# %%
data = ImageClassifierData.from_paths(PATH, tfms=tfms)
learn = ConvLearner.pretrained(arch, data, precompute=True)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]

# %%
learn.fit(1e-2,2)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.850028   0.743045   0.5
#     1      0.641863   0.339012   0.9
# [array([0.33901]), 0.8999999761581421]

# %%
learn.precompute=False
learn.fit(1e-2, 3, cycle_len=1)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.267673   0.317589   0.9
#     1      0.24384    0.244838   1.0
#     2      0.22965    0.179156   1.0
# [array([0.17916]), 1.0]

# %%
learn.sched.plot_lr()

# %%
learn.save('224_lastlayer')

# %%
learn.load('224_lastlayer')

# %%
learn.unfreeze()

# %%
lr=np.array([1e-4,1e-3,1e-2])

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.380869   0.166246   1.0
#     1      0.387518   0.113509   1.0
#     2      0.383306   0.099921   1.0
#     3      0.356383   0.056567   1.0
#     4      0.323668   0.037852   1.0
#     5      0.289057   0.031648   1.0
#     6      0.255062   0.031403   1.0
# [array([0.0314]), 1.0]

# %%
learn.sched.plot_lr()

# %%
learn.save('224_all')

# %%
learn.load('224_all')

# %%
log_preds,y = learn.TTA()
probs = np.mean(np.exp(log_preds),0)

# %%
accuracy_np(probs, y)
# Out:
# 1.0

# %%
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes)
# Out:
# [[10  0]
#  [ 0 10]]
